# %% [markdown]
# # 01 — Data preparation
#
# Course **22AIE301**. Load 20 Newsgroups (sanity check) and arXiv ML/AI abstracts (scientific corpus), then clean, tokenize, and lemmatize.
#
# arXiv is the recommended dataset from the project abstract: titles, abstracts, categories, and timestamps for trend analysis.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.config import DEFAULT_N_DOCS, RANDOM_SEED
from src.data import load_corpus
from src.preprocess import preprocess_frame

# %%
news = load_corpus("20newsgroups", n_docs=DEFAULT_N_DOCS, seed=RANDOM_SEED)
arxiv = load_corpus("arxiv", n_docs=DEFAULT_N_DOCS, seed=RANDOM_SEED)
print(news.shape, arxiv.shape)
news.head(2)

# %%
news_p = preprocess_frame(news)
arxiv_p = preprocess_frame(arxiv)
print("20newsgroups tokens/doc:", news_p["tokens"].map(len).mean())
print("arxiv tokens/doc:", arxiv_p["tokens"].map(len).mean())
print("arxiv year coverage:", arxiv_p["year"].notna().mean())
arxiv_p[["title", "year", "tokens"]].head(3)

# %% [markdown]
# Preprocessing: lowercase, strip URLs/emails/citations, drop stopwords, WordNet lemmatization. Documents with fewer than 8 tokens are removed.
